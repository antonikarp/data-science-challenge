# %% [markdown]
# Import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Read the dataset

# %%
df = pd.read_csv("./Data/2008.csv", encoding='ISO-8859-1', low_memory=False)
df.index.name="Id"
df
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# Id
# 0        2008      1           3          4   2003.0        1955   2211.0
# 1        2008      1           3          4    754.0         735   1002.0
# 2        2008      1           3          4    628.0         620    804.0
# 3        2008      1           3          4    926.0         930   1054.0
# 4        2008      1           3          4   1829.0        1755   1959.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7009723  2008     12          13          6   1002.0         959   1204.0
# 7009724  2008     12          13          6    834.0         835   1021.0
# 7009725  2008     12          13          6    655.0         700    856.0
# 7009726  2008     12          13          6   1251.0        1240   1446.0
# 7009727  2008     12          13          6   1110.0        1103   1413.0
#
# ...

# %% [markdown]
# Group by day of week and mean delay

# %%
df = df.groupby('DayOfWeek')['DepDelay'].mean().reset_index()
df
# Out:
#    DayOfWeek   DepDelay
# 0          1  10.269990
# 1          2   8.976897
# 2          3   8.289761
# 3          4   9.772897
# 4          5  12.158036
# 5          6   8.645681
# 6          7  11.568973

# %% [markdown]
# Map

# %%
days = {1:'Monday', 2:'Tuesday', 3:'Wednesday', 4:'Thursday', 5:'Friday', 6:'Saturday', 7:'Sunday'}
df['DayOfWeek'] = df['DayOfWeek'].map(days)

# %% [markdown]
# Display graph

# %%
ax = df.plot.bar(x='DayOfWeek', y='DepDelay', rot=0, figsize=[14.70, 8.27])
plt.title("Distribution of departure delay over the week days", fontsize = 14, weight = "bold")
plt.ylabel('Departure delay', fontsize = 10, weight = "bold")
plt.xlabel('Day of Week', fontsize = 10, weight = "bold")
plt.show()

# %% [markdown]
# Interpretation:<br>
# Looking at the resulting graph, it can be said that Friday is the worst day to have a flight.<br>
# On the other hand Wednesday is the best option if we want to avoid a delay.
